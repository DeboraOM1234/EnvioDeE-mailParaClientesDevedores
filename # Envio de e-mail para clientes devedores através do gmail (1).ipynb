# %% [markdown]
# # Envio de e-mail para clientes devedores

# %% [markdown]
# ###### Iremos utilizar a base de dados "Clientes.xlsx", na qual existem os clientes que constam como devedores no dia de hoje. Enviaremos e-mails automáticos para esses clientes através do gmail.

# %% [markdown]
# ## 1º) Verificando as informações

# %%
# Importando as bibliotecas:
import pandas as pd
import datetime as dt

# %%
# Lendo o arquivo .CSV e visualizando seus 5 primeiros valores:
clientes = pd.read_excel('Clientes.xlsx')
clientes
# Out:
#              CPF  Valor em aberto Data Prevista para pagamento     Status  \
# 0    44204824413           1195.0                   2022-09-16       Pago
# 1    27333842934           1670.0                   2022-09-26  Em aberto
# 2    27337412934           1345.0                   2022-08-31  Em aberto
# 3    53713111219           1372.0                   2022-10-21  Em aberto
# 4    17537122867           1718.0                   2022-11-18       Pago
# ..           ...              ...                          ...        ...
# 195  26130190204           1060.0                   2022-01-19       Pago
# 196  50695164206           1587.0                   2022-01-21       Pago
# 197  68885370313           1842.0                   2022-01-15       Pago
# 198  58701953352           1604.0                   2022-01-20       Pago
# 199  28986124401           1738.0                   2022-01-27       Pago
#
#                      E-mail   NF
# 0    deboraomatos@gmail.com  197
# 1    deboraomatos@gmail.com  177
# 2    deboraomatos@gmail.com  133
# 3    deboraomatos@gmail.com  155
# 4    deboraomatos@gmail.com  149
# ..                      ...  ...
# 195  deboraomatos@gmail.com  134
# 196  deboraomatos@gmail.com  117
# 197  deboraomatos@gmail.com  107
# 198  deboraomatos@gmail.com  116
# 199  deboraomatos@gmail.com  113
#
# [200 rows x 6 columns]

# %%
# Tipos de variáveis e dimensão do dataframe:
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CPF                           200 non-null    int64
#  1   Valor em aberto               200 non-null    float64
#  2   Data Prevista para pagamento  200 non-null    datetime64[ns]
#  3   Status                        200 non-null    object
#  4   E-mail                        200 non-null    object
#  5   NF                            200 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# ## 2º) Coletando os clientes devedores

# %%
# Definindo a data de hoje:
hoje = dt.datetime.now()
print(hoje)
# Out:
# 2022-08-28 19:20:31.879748

# %%
# Selecionando os clientes com pagamento em aberto:
devedores = clientes.loc[clientes['Status'] == 'Em aberto']
devedores
# Out:
#              CPF  Valor em aberto Data Prevista para pagamento     Status  \
# 1    27333842934           1670.0                   2022-09-26  Em aberto
# 2    27337412934           1345.0                   2022-08-31  Em aberto
# 3    53713111219           1372.0                   2022-10-21  Em aberto
# 5    54769185414           1533.0                   2022-01-13  Em aberto
# 6    44744009510           1411.0                   2022-01-12  Em aberto
# ..           ...              ...                          ...        ...
# 190  71953312562           1657.0                   2022-01-12  Em aberto
# 191  62203137527           1419.0                   2022-01-16  Em aberto
# 192  34219196712           1018.0                   2022-01-28  Em aberto
# 193  26316453421           1487.0                   2022-01-28  Em aberto
# 194  29777295739           1102.0                   2022-01-13  Em aberto
#
#                      E-mail   NF
# 1    deboraomatos@gmail.com  177
# 2    deboraomatos@gmail.com  133
# 3    deboraomatos@gmail.com  155
# 5    deboraomatos@gmail.com  118
# 6    deboraomatos@gmail.com  191
# ..                      ...  ...
# 190  deboraomatos@gmail.com  178
# 191  deboraomatos@gmail.com  200
# 192  deboraomatos@gmail.com  171
# 193  deboraomatos@gmail.com  129
# 194  deboraomatos@gmail.com  127
#
# [108 rows x 6 columns]

# %%
# Selecionando apenas os clientes com pagamento já vencido:
devedores = devedores.loc[devedores['Data Prevista para pagamento']<hoje]
devedores
# Out:
#              CPF  Valor em aberto Data Prevista para pagamento     Status  \
# 5    54769185414           1533.0                   2022-01-13  Em aberto
# 6    44744009510           1411.0                   2022-01-12  Em aberto
# 9    80512149720           1007.0                   2022-01-11  Em aberto
# 10   18783293271           1253.0                   2022-01-27  Em aberto
# 15   49987814992           1901.0                   2022-01-12  Em aberto
# ..           ...              ...                          ...        ...
# 190  71953312562           1657.0                   2022-01-12  Em aberto
# 191  62203137527           1419.0                   2022-01-16  Em aberto
# 192  34219196712           1018.0                   2022-01-28  Em aberto
# 193  26316453421           1487.0                   2022-01-28  Em aberto
# 194  29777295739           1102.0                   2022-01-13  Em aberto
#
#                      E-mail   NF
# 5    deboraomatos@gmail.com  118
# 6    deboraomatos@gmail.com  191
# 9    deboraomatos@gmail.com  172
# 10   deboraomatos@gmail.com  172
# 15   deboraomatos@gmail.com  108
# ..                      ...  ...
# 190  deboraomatos@gmail.com  178
# 191  deboraomatos@gmail.com  200
# 192  deboraomatos@gmail.com  171
# 193  deboraomatos@gmail.com  129
# 194  deboraomatos@gmail.com  127
#
# [105 rows x 6 columns]

# %% [markdown]
# ## 3º) Enviando e-mail pelo Gmail

# %%
# Selecionando as informações que serão utilizadas no corpo do e-mail:
dados = devedores[['Valor em aberto', 'Data Prevista para pagamento', 'E-mail', 'NF']].values.tolist()
dados
# Out:
# [[1533.0, Timestamp('2022-01-13 00:00:00'), 'deboraomatos@gmail.com', 118],
#  [1411.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 191],
#  [1007.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1253.0, Timestamp('2022-01-27 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1901.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 108],
#  [1594.0, Timestamp('2022-01-28 00:00:00'), 'deboraomatos@gmail.com', 112],
#  [1520.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 111],
#  [1666.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 129],
#  [1339.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 179],
#  [1014.0, Timestamp('2022-01-21 00:00:00'), 'deboraomatos@gmail.com', 124],
#  [1061.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 127],
#  [1718.0, Timestamp('2022-01-21 00:00:00'), 'deboraomatos@gmail.com', 145],
#  [1724.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 106],
#  [1927.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 122],
#  [1546.0, Timestamp('2022-01-23 00:00:00'), 'deboraomatos@gmail.com', 114],
#  [1713.0, Timestamp('2022-01-27 00:00:00'), 'deboraomatos@gmail.com', 162],
#  [1044.0, Timestamp('2022-01-13 00:00:00'), 'deboraomatos@gmail.com', 163],
#  [1370.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 135],
#  [1430.0, Timestamp('2022-01-26 00:00:00'), 'deboraomatos@gmail.com', 166],
#  [1438.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 105],
#  [1389.0, Timestamp('2022-01-23 00:00:00'), 'deboraomatos@gmail.com', 155],
#  [1585.0, Timestamp('2022-01-30 00:00:00'), 'deboraomatos@gmail.com', 166],
#  [1815.0, Timestamp('2022-01-25 00:00:00'), 'deboraomatos@gmail.com', 152],
#  [1892.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 102],
#  [1716.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 130],
#  [1031.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 114],
#  [1827.0, Timestamp('2022-01-15 00:00:00'), 'deboraomatos@gmail.com', 145],
#  [1704.0, Timestamp('2022-01-14 00:00:00'), 'deboraomatos@gmail.com', 169],
#  [1488.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 105],
#  [1368.0, Timestamp('2022-01-25 00:00:00'), 'deboraomatos@gmail.com', 122],
#  [1245.0, Timestamp('2022-01-13 00:00:00'), 'deboraomatos@gmail.com', 183],
#  [1218.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 101],
#  [1662.0, Timestamp('2022-01-13 00:00:00'), 'deboraomatos@gmail.com', 159],
#  [1317.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 126],
#  [1851.0, Timestamp('2022-01-21 00:00:00'), 'deboraomatos@gmail.com', 197],
#  [1378.0, Timestamp('2022-01-17 00:00:00'), 'deboraomatos@gmail.com', 175],
#  [1153.0, Timestamp('2022-01-23 00:00:00'), 'deboraomatos@gmail.com', 110],
#  [1701.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 183],
#  [1915.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 148],
#  [1271.0, Timestamp('2022-01-17 00:00:00'), 'deboraomatos@gmail.com', 195],
#  [1451.0, Timestamp('2022-01-24 00:00:00'), 'deboraomatos@gmail.com', 133],
#  [1986.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 197],
#  [1091.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 134],
#  [1624.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 156],
#  [1441.0, Timestamp('2022-01-26 00:00:00'), 'deboraomatos@gmail.com', 126],
#  [1989.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 155],
#  [1594.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 165],
#  [1294.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 103],
#  [1442.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 178],
#  [1216.0, Timestamp('2022-01-21 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1439.0, Timestamp('2022-01-14 00:00:00'), 'deboraomatos@gmail.com', 143],
#  [1273.0, Timestamp('2022-01-18 00:00:00'), 'deboraomatos@gmail.com', 136],
#  [1792.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 145],
#  [1587.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 135],
#  [1201.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 158],
#  [1897.0, Timestamp('2022-01-26 00:00:00'), 'deboraomatos@gmail.com', 158],
#  [1420.0, Timestamp('2022-01-24 00:00:00'), 'deboraomatos@gmail.com', 195],
#  [1400.0, Timestamp('2022-01-27 00:00:00'), 'deboraomatos@gmail.com', 130],
#  [1419.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 176],
#  [1545.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 195],
#  [1834.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 175],
#  [1610.0, Timestamp('2022-01-17 00:00:00'), 'deboraomatos@gmail.com', 184],
#  [1161.0, Timestamp('2022-01-29 00:00:00'), 'deboraomatos@gmail.com', 162],
#  [1602.0, Timestamp('2022-01-26 00:00:00'), 'deboraomatos@gmail.com', 173],
#  [1016.0, Timestamp('2022-01-22 00:00:00'), 'deboraomatos@gmail.com', 127],
#  [1560.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 155],
#  [1972.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 182],
#  [1796.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 156],
#  [1244.0, Timestamp('2022-01-27 00:00:00'), 'deboraomatos@gmail.com', 109],
#  [1632.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1375.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 111],
#  [1663.0, Timestamp('2022-01-14 00:00:00'), 'deboraomatos@gmail.com', 163],
#  [1178.0, Timestamp('2022-01-14 00:00:00'), 'deboraomatos@gmail.com', 152],
#  [1859.0, Timestamp('2022-01-28 00:00:00'), 'deboraomatos@gmail.com', 166],
#  [1911.0, Timestamp('2022-01-30 00:00:00'), 'deboraomatos@gmail.com', 157],
#  [1320.0, Timestamp('2022-01-30 00:00:00'), 'deboraomatos@gmail.com', 182],
#  [1347.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 142],
#  [1875.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 120],
#  [1595.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 145],
#  [1043.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 167],
#  [1054.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 173],
#  [1750.0, Timestamp('2022-01-20 00:00:00'), 'deboraomatos@gmail.com', 140],
#  [1105.0, Timestamp('2022-01-18 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1984.0, Timestamp('2022-01-23 00:00:00'), 'deboraomatos@gmail.com', 127],
#  [1733.0, Timestamp('2022-01-22 00:00:00'), 'deboraomatos@gmail.com', 160],
#  [1812.0, Timestamp('2022-01-14 00:00:00'), 'deboraomatos@gmail.com', 174],
#  [1346.0, Timestamp('2022-01-21 00:00:00'), 'deboraomatos@gmail.com', 114],
#  [1721.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 172],
#  [1838.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 141],
#  [1989.0, Timestamp('2022-01-30 00:00:00'), 'deboraomatos@gmail.com', 193],
#  [1140.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 198],
#  [1714.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 198],
#  [1012.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 164],
#  [1739.0, Timestamp('2022-01-31 00:00:00'), 'deboraomatos@gmail.com', 199],
#  [1875.0, Timestamp('2022-01-11 00:00:00'), 'deboraomatos@gmail.com', 191],
#  [1287.0, Timestamp('2022-01-17 00:00:00'), 'deboraomatos@gmail.com', 140],
#  [1917.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 142],
#  [1139.0, Timestamp('2022-01-24 00:00:00'), 'deboraomatos@gmail.com', 136],
#  [1955.0, Timestamp('2022-01-19 00:00:00'), 'deboraomatos@gmail.com', 148],
#  [1047.0, Timestamp('2022-01-15 00:00:00'), 'deboraomatos@gmail.com', 192],
#  [1657.0, Timestamp('2022-01-12 00:00:00'), 'deboraomatos@gmail.com', 178],
#  [1419.0, Timestamp('2022-01-16 00:00:00'), 'deboraomatos@gmail.com', 200],
#  [1018.0, Timestamp('2022-01-28 00:00:00'), 'deboraomatos@gmail.com', 171],
#  [1487.0, Timestamp('2022-01-28 00:00:00'), 'deboraomatos@gmail.com', 129],
#  [1102.0, Timestamp('2022-01-13 00:00:00'), 'deboraomatos@gmail.com', 127]]

# %%
# Criação do e-mail:
import smtplib
import email.message

for dado in dados:
    valor = dado[0]
    prazo = dado[1].strftime("%d/%m/%Y")
    destinatario = dado[2]
    NF = dado[3]
    
    
    def enviar_email():  
        corpo_email = f"""
        <p>Caro cliente,<p>
        <p> <p>
        <p>Informo que o pagamento referente à Nota Fiscal(NF) {NF} consta em atraso. O valor total é de R${valor} e a data de vencimento foi em {prazo}.<p>
        <p>Estamos à disposição para qualquer suporte nos canais: (XX)XXXX-XXXX ou XXX@gmail.com.<p>

        <p> <p>
        <p>Atenciosamente.<p>
        <p>Lojas DeboraMatos<p>
        """

        msg = email.message.Message()
        msg['Subject'] = "Lembrete de atraso no pagamento - Lojas DeboraMatos"
        msg['From'] = 'deboraomatos@gmail.com'
        msg['To'] = destinatario
        password = 'lumpktqudzspbrsz' 
        msg.add_header('Content-Type', 'text/html')
        msg.set_payload(corpo_email)

        s = smtplib.SMTP('smtp.gmail.com: 587')
        s.starttls()
        # Login Credentials for sending the mail
        s.login(msg['From'], password)
        s.sendmail(msg['From'], [msg['To']], msg.as_string().encode('utf-8'))
        print('Email enviado')

    enviar_email()
# Out:
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
# Email enviado
